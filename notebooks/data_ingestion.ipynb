# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Abhi\Documents\youtube-comment-analysis\mlops-youtube-comment-analysis\.venv\Scripts\python.exe

# %%
import requests

url='https://raw.githubusercontent.com/Himanshu-1703/reddit-sentiment-analysis/refs/heads/main/data/reddit.csv'

response=requests.get(url)

with open('../data/raw/comments.csv','wb') as f:
    f.write(response.content)

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Abhi\\Documents\\youtube-comment-analysis\\mlops-youtube-comment-analysis\\notebooks'
